# %%
a=[1,2,3,4]
b=[2,4,6,8]
plt.bar(a,b)
plt.show()

# %%
from matplotlib import pyplot as plt
a=[1,2,3,4]
b=[5,6,7,8]
fig,axs=plt.subplots(1,2,figsize=(12,8))
axs[0].plot(a,b)
axs[0].set_title("LINE")
axs[1].bar(a,b)
axs[1].set_title("BAR")
plt.show()

# %%
from matplotlib import pyplot as plt
a=[1,2,3,4]
b=[2,4,6,8]

# %%
a=[1,2,3,4]
b=[2,4,6,8]
plt.scatter(a,b)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("LAHAA EP ")
plt.show()

# %%
a=[1,2,3,4]
b=[2,4,6,8]
plt.stem(a,b)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("LAHAA EP ")
plt.show()

# %%
a=[1,2,3,4]
b=[2,4,6,8]
plt.barh(a,b)
plt.show()

# %%
a=[1,2,3,3,3,2,2,2,2,2,5,4,3,2,5,5,5,5,5,5,5,]
plt.hist(a)
plt.show()

# %%
sizes = [30, 25, 20, 25]


plt.pie(sizes,labels=['MECH','IT','CSE','EEE'])

plt.title("HITAM EP'S")
plt.show()
