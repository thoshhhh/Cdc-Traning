# %%
import pandas as pd
data=pd.read_csv('dataset.csv')
data
# Out:
#    EMP ID      ENAME  EAGE  GENDER DOMAIN  PROJECTS   DESIGNATION  EXPERIENCE  \
# 0       1   SAI TEJA    22    MALE    CSE         2  DATA ANALYST           2
# 1       2     NAVEEN    34    MALE    CSE         3  DATA ANALYST           3
# 2       3     HARSHA    44    MALE    CSE         4  DATA ANALYST           4
# 3       4      TANUJ    22    MALE    CSE         2  DATA ANALYST           2
# 4       5    KARTHIK    23    MALE    CSE         3  DATA ANALYST           3
# 5       6    ARAVIND    43    MALE    CSE         1  DATA ANALYST           2
# 6       7  CHARVITHA    43  FEMALE    CSE         2  DATA ANALYST           3
# 7       8  RAKSHITHA    23  FEMALE    CSE         3  DATA ANALYST           4
# 8       9    ANUSHKA    22  FEMALE    CSE         3  DATA ANALYST           4
# 9      10    PRABHAS    21    MALE    CSE         4  DATA ANALYST           2
#
#    SALARY
# 0       4
# 1       5
# 2       2
# 3       6
# 4       7
# 5       8
# 6       6
# 7       5
# ...

# %%
data=pd.read_csv('dataset.csv')
data
# Out:
#    EMP ID      ENAME  EAGE  GENDER DOMAIN  PROJECTS   DESIGNATION  EXPERIENCE  \
# 0       1   SAI TEJA    22    MALE    CSE         2  DATA ANALYST           2
# 1       2     NAVEEN    34    MALE    CSE         3  DATA ANALYST           3
# 2       3     HARSHA    44    MALE    CSE         4  DATA ANALYST           4
# 3       4      TANUJ    22    MALE    CSE         2  DATA ANALYST           2
# 4       5    KARTHIK    23    MALE    CSE         3  DATA ANALYST           3
# 5       6    ARAVIND    43    MALE    CSE         1  DATA ANALYST           2
# 6       7  CHARVITHA    43  FEMALE    CSE         2  DATA ANALYST           3
# 7       8  RAKSHITHA    23  FEMALE    CSE         3  DATA ANALYST           4
# 8       9    ANUSHKA    22  FEMALE    CSE         3  DATA ANALYST           4
# 9      10    PRABHAS    21    MALE    CSE         4  DATA ANALYST           2
#
#    SALARY
# 0       4
# 1       5
# 2       2
# 3       6
# 4       7
# 5       8
# 6       6
# 7       5
# ...

# %%
data=pd.read_csv('dataset.csv')
data
# Out:
#     EMP ID      ENAME  EAGE  GENDER DOMAIN  PROJECTS   DESIGNATION  \
# 0        1   SAI TEJA    22    MALE    CSE       2.0  DATA ANALYST
# 1        2     NAVEEN    34    MALE    CSE       3.0  DATA ANALYST
# 2        3     HARSHA    44    MALE    CSE       4.0  DATA ANALYST
# 3        4      TANUJ    22    MALE    CSE       2.0  DATA ANALYST
# 4        5    KARTHIK    23    MALE    CSE       3.0  DATA ANALYST
# 5        6    ARAVIND    43    MALE    CSE       1.0  DATA ANALYST
# 6        7  CHARVITHA    43  FEMALE    CSE       2.0  DATA ANALYST
# 7        8  RAKSHITHA    23  FEMALE    CSE       3.0  DATA ANALYST
# 8        9    ANUSHKA    22  FEMALE    CSE       3.0  DATA ANALYST
# 9       10    PRABHAS    21    MALE    CSE       4.0  DATA ANALYST
# 10      11       RAVI    22    MALE    NaN       NaN  DATA ANALYST
#
#     EXPERIENCE  SALARY
# 0            2       4
# 1            3       5
# 2            4       2
# 3            2       6
# 4            3       7
# ...

# %%
data.describe()
# Out:
#           EMP ID       EAGE   PROJECTS  EXPERIENCE     SALARY
# count  11.000000  11.000000  10.000000   11.000000  11.000000
# mean    6.000000  29.000000   2.700000    2.909091   6.818182
# std     3.316625   9.869144   0.948683    0.831209   3.600505
# min     1.000000  21.000000   1.000000    2.000000   2.000000
# 25%     3.500000  22.000000   2.000000    2.000000   5.000000
# 50%     6.000000  23.000000   3.000000    3.000000   6.000000
# 75%     8.500000  38.500000   3.000000    3.500000   7.500000
# max    11.000000  44.000000   4.000000    4.000000  16.000000

# %%
data[["ENAME","DESIGNATION","EAGE"]]
# Out:
#         ENAME   DESIGNATION  EAGE
# 0    SAI TEJA  DATA ANALYST    22
# 1      NAVEEN  DATA ANALYST    34
# 2      HARSHA  DATA ANALYST    44
# 3       TANUJ  DATA ANALYST    22
# 4     KARTHIK  DATA ANALYST    23
# 5     ARAVIND  DATA ANALYST    43
# 6   CHARVITHA  DATA ANALYST    43
# 7   RAKSHITHA  DATA ANALYST    23
# 8     ANUSHKA  DATA ANALYST    22
# 9     PRABHAS  DATA ANALYST    21
# 10       RAVI  DATA ANALYST    22

# %%
data.head()
# Out:
#    EMP ID     ENAME  EAGE GENDER DOMAIN  PROJECTS   DESIGNATION  EXPERIENCE  \
# 0       1  SAI TEJA    22   MALE    CSE         2  DATA ANALYST           2
# 1       2    NAVEEN    34   MALE    CSE         3  DATA ANALYST           3
# 2       3    HARSHA    44   MALE    CSE         4  DATA ANALYST           4
# 3       4     TANUJ    22   MALE    CSE         2  DATA ANALYST           2
# 4       5   KARTHIK    23   MALE    CSE         3  DATA ANALYST           3
#
#    SALARY
# 0       4
# 1       5
# 2       2
# 3       6
# 4       7
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['EMP ID'].plot(kind='hist', bins=20, title='EMP ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['EAGE'].plot(kind='hist', bins=20, title='EAGE')
# ...

# %%
print(data['GENDER'].value_counts())
# Out:
# GENDER
# MALE      8
# FEMALE    3
# Name: count, dtype: int64

# %%
print(data['DESIGNATION'].value_counts())
# Out:
# DESIGNATION
# DATA ANALYST    11
# Name: count, dtype: int64

# %%
print(data['PROJECTS'].max())
print(data['SALARY'].min())
# Out:
# 4.0
# 2

# %%
print(data.sort_values(by="SALARY",ascending=True))
# Out:
#     EMP ID      ENAME  EAGE  GENDER DOMAIN  PROJECTS   DESIGNATION  \
# 2        3     HARSHA    44    MALE    CSE       4.0  DATA ANALYST
# 0        1   SAI TEJA    22    MALE    CSE       2.0  DATA ANALYST
# 1        2     NAVEEN    34    MALE    CSE       3.0  DATA ANALYST
# 7        8  RAKSHITHA    23  FEMALE    CSE       3.0  DATA ANALYST
# 3        4      TANUJ    22    MALE    CSE       2.0  DATA ANALYST
# 6        7  CHARVITHA    43  FEMALE    CSE       2.0  DATA ANALYST
# 4        5    KARTHIK    23    MALE    CSE       3.0  DATA ANALYST
# 8        9    ANUSHKA    22  FEMALE    CSE       3.0  DATA ANALYST
# 5        6    ARAVIND    43    MALE    CSE       1.0  DATA ANALYST
# 9       10    PRABHAS    21    MALE    CSE       4.0  DATA ANALYST
# 10      11       RAVI    22    MALE    NaN       NaN  DATA ANALYST
#
#     EXPERIENCE  SALARY
# 2            4       2
# 0            2       4
# 1            3       5
# 7            4       5
# 3            2       6
# ...

# %%
print(data.nlargest(5,'PROJECTS'))
# Out:
#    EMP ID      ENAME  EAGE  GENDER DOMAIN  PROJECTS   DESIGNATION  EXPERIENCE  \
# 2       3     HARSHA    44    MALE    CSE       4.0  DATA ANALYST           4
# 9      10    PRABHAS    21    MALE    CSE       4.0  DATA ANALYST           2
# 1       2     NAVEEN    34    MALE    CSE       3.0  DATA ANALYST           3
# 4       5    KARTHIK    23    MALE    CSE       3.0  DATA ANALYST           3
# 7       8  RAKSHITHA    23  FEMALE    CSE       3.0  DATA ANALYST           4
#
#    SALARY
# 2       2
# 9       9
# 1       5
# 4       7
# 7       5

# %%
print(data.groupby('DOMAIN')["PROJECTS"].mean())
# Out:
# DOMAIN
# CSE    2.7
# Name: PROJECTS, dtype: float64

# %%
data.tail()
# Out:
#    EMP ID      ENAME  EAGE  GENDER DOMAIN  PROJECTS   DESIGNATION  EXPERIENCE  \
# 5       6    ARAVIND    43    MALE    CSE         1  DATA ANALYST           2
# 6       7  CHARVITHA    43  FEMALE    CSE         2  DATA ANALYST           3
# 7       8  RAKSHITHA    23  FEMALE    CSE         3  DATA ANALYST           4
# 8       9    ANUSHKA    22  FEMALE    CSE         3  DATA ANALYST           4
# 9      10    PRABHAS    21    MALE    CSE         4  DATA ANALYST           2
#
#    SALARY
# 5       8
# 6       6
# 7       5
# 8       7
# 9       9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EMP ID       10 non-null     int64
#  1   ENAME        10 non-null     object
#  2   EAGE         10 non-null     int64
#  3   GENDER       10 non-null     object
#  4   DOMAIN       10 non-null     object
#  5   PROJECTS     10 non-null     int64
#  6   DESIGNATION  10 non-null     object
#  7   EXPERIENCE   10 non-null     int64
#  8   SALARY       10 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 852.0+ bytes
